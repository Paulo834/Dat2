# %%
# %ls
# Out:
# 02_00_data_wrangling.ipynb  Class2.ipynb          pokemon.csv
# adult.csv                   coches.csv            README.md
# airline_data.csv            cwurData.csv          reg_data.csv
# antropometria00.csv         data.csv              requirements.txt
# antropometria-dataset.csv   datasets/             sample_pivot.csv
# Book3.csv                   headbrain.csv         tips.csv
# Canada.xlsx                 mic2.xlsx             Untitled1.ipynb
# Cartwheeldata.csv           mic.xlsx              Untitled.ipynb
# census.csv                  movies.csv            weight-height.csv
# Class1                      nhanes_2015_2016.csv

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       reg_data.csv
# Book3.csv                  headbrain.csv  sample_pivot.csv
# Canada.xlsx                mic2.xlsx      tips.csv
# Cartwheeldata.csv          mic.xlsx       weight-height.csv

# %%
import pandas as pd

# %%
pip install xlrd
# Out:
# ...
#      |████████████████████████████████| 96 kB 3.1 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
path ='datasets/Canada.xlsx'

# %%
pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 4.8 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel(path,
                   engine = 'openpyxl',
                   sheet_name = 'Canada by Citizenship',
                   skiprows = range(20),
                   skipfooter = 2
                  )
df.head(2)
# Out:
#          Type    Coverage       OdName   AREA AreaName     REG  \
# 0  Immigrants  Foreigners  Afghanistan  935.0     Asia  5501.0
# 1  Immigrants  Foreigners      Albania  908.0   Europe   925.0
#
#            RegName    DEV             DevName  1980  ...    2012    2013  \
# 0    Southern Asia  902.0  Developing regions  16.0  ...  2635.0  2004.0
# 1  Southern Europe  901.0   Developed regions   1.0  ...   620.0   603.0
#
#    Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 48  Unnamed: 49  Unnamed: 50
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
#
# [2 rows x 51 columns]

# %%
df.drop(['Type','Coverage','AREA','REG','DEV','DevName'],axis = 1,
         inplace = True)

# %%
df.columns
# Out:
# Index([     'OdName',    'AreaName',     'RegName',          1980,
#                 1981,          1982,          1983,          1984,
#                 1985,          1986,          1987,          1988,
#                 1989,          1990,          1991,          1992,
#                 1993,          1994,          1995,          1996,
#                 1997,          1998,          1999,          2000,
#                 2001,          2002,          2003,          2004,
#                 2005,          2006,          2007,          2008,
#                 2009,          2010,          2011,          2012,
#                 2013, 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
#        'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49',
#        'Unnamed: 50'],
#       dtype='object')

# %%
df = pd.read_excel(path,
                   engine = 'openpyxl',
                   sheet_name = 'Canada by Citizenship',
                   skiprows = range(20),
                   skipfooter = 2
                  )
df.head(2)
# Out:
#          Type    Coverage       OdName   AREA AreaName     REG  \
# 0  Immigrants  Foreigners  Afghanistan  935.0     Asia  5501.0
# 1  Immigrants  Foreigners      Albania  908.0   Europe   925.0
#
#            RegName    DEV             DevName  1980  ...    2012    2013  \
# 0    Southern Asia  902.0  Developing regions  16.0  ...  2635.0  2004.0
# 1  Southern Europe  901.0   Developed regions   1.0  ...   620.0   603.0
#
#    Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 48  Unnamed: 49  Unnamed: 50
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
#
# [2 rows x 51 columns]

# %% [markdown]
# # Description of my dataset

# %% [markdown]
# This is a dataset, explains the inmigrants to Canada from various countries from 1980 to 2013.

# %% [markdown]
# # My variables of interest
# * OdName: the name of the country,
# * AreaName: is the name of the continent

# %% [markdown]
# 1. How many people reached Canada from Japan durin 1980 to 2013?

# %%
df.rename(columns = {'OdName': 'Country',
          'AreaName': 'Continent',
          'RegName': 'Region'},
          inplace = True,
         )
df.head()
# Out:
#          Type    Coverage         Country   AREA Continent     REG  \
# 0  Immigrants  Foreigners     Afghanistan  935.0      Asia  5501.0
# 1  Immigrants  Foreigners         Albania  908.0    Europe   925.0
# 2  Immigrants  Foreigners         Algeria  903.0    Africa   912.0
# 3  Immigrants  Foreigners  American Samoa  909.0   Oceania   957.0
# 4  Immigrants  Foreigners         Andorra  908.0    Europe   925.0
#
#             Region    DEV             DevName  1980  ...    2012    2013  \
# 0    Southern Asia  902.0  Developing regions  16.0  ...  2635.0  2004.0
# 1  Southern Europe  901.0   Developed regions   1.0  ...   620.0   603.0
# 2  Northern Africa  902.0  Developing regions  80.0  ...  3774.0  4331.0
# 3        Polynesia  902.0  Developing regions   0.0  ...     0.0     0.0
# 4  Southern Europe  901.0   Developed regions   0.0  ...     1.0     1.0
#
#    Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  \
# ...

# %%
df.iloc[:,3:]
# Out:
#        AREA Continent     REG           Region    DEV             DevName  \
# 0     935.0      Asia  5501.0    Southern Asia  902.0  Developing regions
# 1     908.0    Europe   925.0  Southern Europe  901.0   Developed regions
# 2     903.0    Africa   912.0  Northern Africa  902.0  Developing regions
# 3     909.0   Oceania   957.0        Polynesia  902.0  Developing regions
# 4     908.0    Europe   925.0  Southern Europe  901.0   Developed regions
# ...     ...       ...     ...              ...    ...                 ...
# 1008    NaN       NaN     NaN              NaN    NaN                 NaN
# 1009    NaN       NaN     NaN              NaN    NaN                 NaN
# 1010    NaN       NaN     NaN              NaN    NaN                 NaN
# 1011    NaN       NaN     NaN              NaN    NaN                 NaN
# 1012    NaN       NaN     NaN              NaN    NaN                 NaN
#
#       1980  1981  1982  1983  ...    2012    2013  Unnamed: 43  Unnamed: 44  \
# ...

# %%
df['Total'] = df.iloc[:,3:].sum(axis = 1)

# %%
df.iloc[:,3:]
# Out:
#                Continent     REG           Region    DEV             DevName  \
# Country
# Afghanistan         Asia  5501.0    Southern Asia  902.0  Developing regions
# Albania           Europe   925.0  Southern Europe  901.0   Developed regions
# Algeria           Africa   912.0  Northern Africa  902.0  Developing regions
# American Samoa   Oceania   957.0        Polynesia  902.0  Developing regions
# Andorra           Europe   925.0  Southern Europe  901.0   Developed regions
# ...                  ...     ...              ...    ...                 ...
# NaN                  NaN     NaN              NaN    NaN                 NaN
# NaN                  NaN     NaN              NaN    NaN                 NaN
# NaN                  NaN     NaN              NaN    NaN                 NaN
# NaN                  NaN     NaN              NaN    NaN                 NaN
# NaN                  NaN     NaN              NaN    NaN                 NaN
#
# ...

# %%
df.set_index('Country',inplace = True)
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_80/4258281870.py in <module>
# ----> 1 df.set_index('Country',inplace = True)
#       2 df.head(2)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Country'] are in the columns"

# %%
df.loc['Japan','Total']
# Out:
# 29514.0
